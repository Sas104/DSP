# %%
import numpy as np
import matplotlib.pyplot as plt
x=[1,2,3,2,1]
y=[3,2,1,0,0]
Ys=[3,2,1,0,0]
#print(Ys)
s=np.multiply(x,y)
#print(s)
for i in range(3):
    for j in range(len(y)-1):
        y[j]=y[j+1]
    #print(y)
    s+=np.multiply(x,y)
    #print(s)
    for j in range(len(y)-1):
        Ys[len(y)-1-j]=Ys[len(y)-2-j]
    Ys[i]=0
    s+=np.multiply(x,Ys)
    #print(Ys)
print(s)
t=np.arange(0,5,1)
plt.plot(t,s)
# Out:
# [ 6 12 18 12  3]

# %%
import numpy as np
import matplotlib.pyplot as plt
x=[1,2,3,2,1]
y=[3,2,1,0,0]
Ys=[3,2,1,0,0]
#print(Ys)
r1=np.zeros(m+n)
s=np.multiply(x,y)
#print(s)
for i in range(3):
    for j in range(len(y)-1):
        y[j]=y[j+1]
    #print(y)
    s+=np.multiply(x,y)
    #print(s)
    for j in range(len(y)-1):
        Ys[len(y)-1-j]=Ys[len(y)-2-j]
    Ys[i]=0
    s+=np.multiply(x,Ys)
    #print(Ys)
print(s)
t=np.arange(0,5,1)
plt.plot(t,s)
# Out:
# 6
# [0. 0. 0. 0. 0. 0. 0. 0.]
