# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import firwin, lfilter, freqz

# Create time vector
sample_rate = 1000  # Sample rate in Hz
duration = 5  # Duration of the signal in seconds
t = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)

# Create three sinusoidal signals
freq_1 = 0.5
freq_2 = 30
freq_3 = 100
signal_1 = np.sin(2 * np.pi * freq_1 * t)
signal_2 = np.sin(2 * np.pi * freq_2 * t)
signal_3 = np.sin(2 * np.pi * freq_3 * t)

# Add the three signals together
sum_signal = signal_1 + signal_2 + signal_3

# Design the FIR band-pass filter
low_cutoff_freq = 15  # Low cutoff frequency in Hz
numtaps = 101  # Number of filter taps
b = firwin(numtaps, low_cutoff_freq, pass_zero=True, fs=sample_rate)

# Compute frequency response of the filter
w, h = freqz(b, worN=8000)
freq = 0.5 * sample_rate * w / np.pi
db = 20 * np.log10(abs(h))

plt.plot(freq, db)
plt.title('Digital low pass FIR Filter Frequency Response')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude (dB)')
plt.grid()


plt.figure(figsize=(12, 6))

# Apply the FIR band-pass filter
filtered_signal = lfilter(b, 1.0, sum_signal)

# Compute the FFT of the signals
fft_signal = np.fft.fft(sum_signal)
fft_filtered_signal = np.fft.fft(filtered_signal)
freq_fft = np.fft.fftfreq(len(t), d=1.0/sample_rate)

# Plot the original and filtered signals with their FFTs
plt.subplot(2, 2, 1)
plt.plot(t, sum_signal, label='Sum of 0.5Hz, 30Hz, and 100Hz Signals')
plt.title('Original Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(freq_fft, np.abs(fft_signal), label='FFT of Sum Signal')
plt.title('FFT of Original Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t, filtered_signal, label='Filtered Signal')
plt.title('Filtered Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(freq_fft, np.abs(fft_filtered_signal), label='FFT of Filtered Signal')
plt.title('FFT of Filtered Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import firwin, lfilter, freqz

# Create time vector
sample_rate = 1000  # Sample rate in Hz
duration = 5  # Duration of the signal in seconds
t = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)

# Create three sinusoidal signals
freq_1 = 0.5
freq_2 = 30
freq_3 = 100
signal_1 = np.sin(2 * np.pi * freq_1 * t)
signal_2 = np.sin(2 * np.pi * freq_2 * t)
signal_3 = np.sin(2 * np.pi * freq_3 * t)

# Add the three signals together
sum_signal = signal_1 + signal_2 + signal_3

# Design the FIR band-pass filter
low_cutoff_freq = 15  # Low cutoff frequency in Hz
high_cutoff_freq = 40  # High cutoff frequency in Hz
numtaps = 101  # Number of filter taps
b = firwin(numtaps, [low_cutoff_freq, high_cutoff_freq], pass_zero=False, fs=sample_rate)

# Compute frequency response of the filter
w, h = freqz(b, worN=8000)
freq = 0.5 * sample_rate * w / np.pi
db = 20 * np.log10(abs(h))

plt.plot(freq, db)
plt.title('Digital Band pass FIR Filter Frequency Response')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude (dB)')
plt.grid()


plt.figure(figsize=(12, 6))

# Apply the FIR band-pass filter
filtered_signal = lfilter(b, 1.0, sum_signal)

# Compute the FFT of the signals
fft_signal = np.fft.fft(sum_signal)
fft_filtered_signal = np.fft.fft(filtered_signal)
freq_fft = np.fft.fftfreq(len(t), d=1.0/sample_rate)

# Plot the original and filtered signals with their FFTs
plt.subplot(2, 2, 1)
plt.plot(t, sum_signal, label='Sum of 0.5Hz, 30Hz, and 100Hz Signals')
plt.title('Original Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(freq_fft, np.abs(fft_signal), label='FFT of Sum Signal')
plt.title('FFT of Original Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t, filtered_signal, label='Filtered Signal')
plt.title('Filtered Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(freq_fft, np.abs(fft_filtered_signal), label='FFT of Filtered Signal')
plt.title('FFT of Filtered Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import firwin, lfilter, freqz

# Create time vector
sample_rate = 1000  # Sample rate in Hz
duration = 5  # Duration of the signal in seconds
t = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)

# Create three sinusoidal signals
freq_1 = 0.5
freq_2 = 30
freq_3 = 100
signal_1 = np.sin(2 * np.pi * freq_1 * t)
signal_2 = np.sin(2 * np.pi * freq_2 * t)
signal_3 = np.sin(2 * np.pi * freq_3 * t)

# Add the three signals together
sum_signal = signal_1 + signal_2 + signal_3

# Design the FIR band-pass filter
high_cutoff_freq = 50  # High cutoff frequency in Hz
numtaps = 101  # Number of filter taps
b = firwin(numtaps, high_cutoff_freq, pass_zero=False, fs=sample_rate)

# Compute frequency response of the filter
w, h = freqz(b, worN=8000)
freq = 0.5 * sample_rate * w / np.pi
db = 20 * np.log10(abs(h))

plt.plot(freq, db)
plt.title('Digital High pass FIR Filter Frequency Response')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude (dB)')
plt.grid()


plt.figure(figsize=(12, 6))

# Apply the FIR band-pass filter
filtered_signal = lfilter(b, 1.0, sum_signal)

# Compute the FFT of the signals
fft_signal = np.fft.fft(sum_signal)
fft_filtered_signal = np.fft.fft(filtered_signal)
freq_fft = np.fft.fftfreq(len(t), d=1.0/sample_rate)

# Plot the original and filtered signals with their FFTs
plt.subplot(2, 2, 1)
plt.plot(t, sum_signal, label='Sum of 0.5Hz, 30Hz, and 100Hz Signals')
plt.title('Original Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(freq_fft, np.abs(fft_signal), label='FFT of Sum Signal')
plt.title('FFT of Original Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t, filtered_signal, label='Filtered Signal')
plt.title('Filtered Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(freq_fft, np.abs(fft_filtered_signal), label='FFT of Filtered Signal')
plt.title('FFT of Filtered Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import firwin, lfilter, freqz

# Create time vector
sample_rate = 1000  # Sample rate in Hz
duration = 5  # Duration of the signal in seconds
t = np.linspace(0, duration, int(sample_rate * duration), endpoint=False)

# Create three sinusoidal signals
freq_1 = 0.5
freq_2 = 30
freq_3 = 100
signal_1 = np.sin(2 * np.pi * freq_1 * t)
signal_2 = np.sin(2 * np.pi * freq_2 * t)
signal_3 = np.sin(2 * np.pi * freq_3 * t)

# Add the three signals together
sum_signal = signal_1 + signal_2 + signal_3

# Design the FIR band-pass filter to reject the notch frequency
low_cutoff_freq = 10 # Low cutoff frequency in Hz
high_cutoff_freq = 50  # High cutoff frequency in Hz
numtaps = 101 # Number of filter taps
b = firwin(numtaps, [low_cutoff_freq, high_cutoff_freq], pass_zero=True, fs=sample_rate)


# Compute frequency response of the filter
w, h = freqz(b, worN=8000)
freq = 0.5 * sample_rate * w / np.pi
db = 20 * np.log10(abs(h))

plt.plot(freq, db)
plt.title('Digital FIR Filter Frequency Response')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude (dB)')
plt.grid()


plt.figure(figsize=(12, 6))

# Apply the FIR band-pass filter
filtered_signal = lfilter(b, 1.0, sum_signal)

# Compute the FFT of the signals
fft_signal = np.fft.fft(sum_signal)
fft_filtered_signal = np.fft.fft(filtered_signal)
freq_fft = np.fft.fftfreq(len(t), d=1.0/sample_rate)

# Plot the original and filtered signals with their FFTs
plt.subplot(2, 2, 1)
plt.plot(t, sum_signal, label='Sum of 0.5Hz, 30Hz, and 100Hz Signals')
plt.title('Original Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(freq_fft, np.abs(fft_signal), label='FFT of Sum Signal')
plt.title('FFT of Original Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(t, filtered_signal, label='Filtered Signal')
plt.title('Filtered Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(freq_fft, np.abs(fft_filtered_signal), label='FFT of Filtered Signal')
plt.title('FFT of Filtered Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
